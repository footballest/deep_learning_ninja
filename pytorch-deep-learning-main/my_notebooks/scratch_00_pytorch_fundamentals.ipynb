# %%
import torch

# %%
x = torch.rand(3, 4)

# %%
print(x)
# Out:
# tensor([[0.9844, 0.8552, 0.1004, 0.4718],
#         [0.4434, 0.8952, 0.3436, 0.5343],
#         [0.1036, 0.1123, 0.3358, 0.1971]])
