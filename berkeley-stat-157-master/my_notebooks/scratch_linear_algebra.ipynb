# %%
import mxnet as mx

# %%
from mxnet import nd

# %%
x = nd.array([3.0])
y = nd.array([2.0])

# %%
x, y
# Out:
# (
#  [3.]
#  <NDArray 1 @cpu(0)>,
#
#  [2.]
#  <NDArray 1 @cpu(0)>)

# %%
x.asscalar()
# Out:
# 3.0

# %%
x
# Out:
# [3.]
# <NDArray 1 @cpu(0)>

# %%
z = nd.arange(12)

# %%
z.shape
# Out:
# (12,)

# %%
z.reshape((3,4))

# %%
A = nd.arange(20).reshape((2,10))

# %%
A
